# %% [markdown]
# <a href="https://colab.research.google.com/github/LSRomero/Procedimentos_hospitalares_SUS_2008a2021/blob/main/Notebooks/Bootcamp_Datascience_Alura_2021_M%C3%B3dulo_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploração de dados Datasus 2008 a 2021

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A085016189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Região/Unidade da Federação     2008/Jan  ...     2021/Set         Total
# 0                Região Norte  31111673.48  ...  53712399.21  1.039418e+10
# 1                 .. Rondônia   1388528.39  ...  10345616.78  1.088060e+09
# 2                     .. Acre    902416.00  ...            -  4.752903e+08
# 3                 .. Amazonas   4735529.42  ...  19840265.30  2.061943e+09
# 4                  .. Roraima    657889.53  ...   3150835.05  3.525463e+08
#
# [5 rows x 167 columns]

# %%
dados.tail()
# Out:
#    Região/Unidade da Federação     2008/Jan  ...      2021/Set         Total
# 27         Região Centro-Oeste  30229247.60  ...  152299588.72  1.306161e+10
# 28       .. Mato Grosso do Sul   5377392.11  ...   32338424.49  2.516383e+09
# 29              .. Mato Grosso   4795299.01  ...   27274369.25  2.386584e+09
# 30                    .. Goiás  15310637.29  ...   64176809.02  5.380181e+09
# 31         .. Distrito Federal   4745919.19  ...   28509985.96  2.778457e+09
#
# [5 rows x 167 columns]

# %%
dados.mean()
# Out:
# 2008/Jan    2.552655e+07
# 2008/Fev    3.832339e+07
# 2008/Mar    4.150269e+07
# 2008/Abr    4.291643e+07
# 2008/Mai    4.473773e+07
#                 ...
# 2021/Mai    1.342239e+08
# 2021/Jun    1.395973e+08
# 2021/Jul    1.377022e+08
# 2021/Ago    1.266231e+08
# Total       1.156330e+10
# Length: 164, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Columns: 167 entries, Região/Unidade da Federação to Total
# dtypes: float64(164), object(3)
# memory usage: 41.9+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan      25526553.70
# 2008/Fev      38323391.83
# 2008/Mar      41502691.15
# 2008/Abr      42916428.84
# 2008/Mai      44737727.47
#                 ...
# 2021/Mai     134223875.74
# 2021/Jun     139597316.43
# 2021/Jul     137702232.10
# 2021/Ago     126623119.88
# Total      11563303938.37
# Length: 164, dtype: float64

# %%
dados["2021/Ago"]
# Out:
# 0    101341124.70
# 1     12427865.05
# 2      4138751.64
# 3     22731356.54
# 4      3781921.16
# 5     43262884.30
# 6      5263137.94
# 7      9735208.07
# 8    457265794.37
# 9     41501696.81
# 10    27694895.48
# 11    75731882.46
# 12    32369373.29
# 13    28082449.35
# 14   102801016.63
# 15    24723159.91
# 16    14297739.10
# 17   110063581.34
# 18   879959268.27
# 19   241931842.85
# 20    44627947.75
# 21   133050914.66
# 22   460348563.01
# 23   415137968.41
# 24   178040081.29
# 25   102528877.83
# 26   134569009.29
# 27   172265762.29
# 28    36310521.96
# 29    37763607.95
# 30    70902865.44
# 31    27288766.94
# Name: 2021/Ago, dtype: float64

# %%
dados["2021/Ago"].mean()
# Out:
# 126623119.87749997

# %%
dados.plot (x="Região/Unidade da Federação",y= "2021/Ago" )

# %%
dados.plot(x="Região/Unidade da Federação", y="2021/Ago", kind="bar", figsize=(9,6))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Região/Unidade da Federação", y="2021/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()
